# %% [markdown]
# <a href="https://colab.research.google.com/github/pamellaOliveira/Educational-Data-Mining/blob/master/AbrindoCSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("s")
# Out:
# s

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4bc4f858-f8ce-420e-a996-c24f06d0c689" name="files[]" multiple disabled />
#      <output id="result-4bc4f858-f8ce-420e-a996-c24f06d0c689">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving baseGeral.csv to baseGeral.csv

# %%
import pandas as pd

df = pd.read_csv('baseGeral.csv',encoding = "UTF-8", sep = ";")
df
# Out:
#            Curso  Semestre  ...  DESEMPENHO DESEMPENHO_BINARIO
# 0      Pedagogia    2014.2  ...       3,375                  1
# 1       Biologia    2013.2  ...           0                  1
# 2      Pedagogia    2014.1  ...         0,5                  1
# 3      Pedagogia    2016.1  ...        9,15                  0
# 4       Biologia    2013.2  ...       6,275                  0
# ...          ...       ...  ...         ...                ...
# 30212   Biologia    2014.1  ...         4,8                  0
# 30213     Letras    2010.2  ...         7,3                  0
# 30214     Letras    2014.1  ...        2,25                  1
# 30215     Letras    2014.1  ...           0                  1
# 30216   Biologia    2014.2  ...         4,2                  0
#
# [30217 rows x 63 columns]

# %%
# Especificando o cabeçalho do arquivo
df = pd.read_csv("baseGeral.csv", encoding = "UTF-8", sep = ";", header=0)
df
# Out:
#            Curso  Semestre  ...  DESEMPENHO DESEMPENHO_BINARIO
# 0      Pedagogia    2014.2  ...       3,375                  1
# 1       Biologia    2013.2  ...           0                  1
# 2      Pedagogia    2014.1  ...         0,5                  1
# 3      Pedagogia    2016.1  ...        9,15                  0
# 4       Biologia    2013.2  ...       6,275                  0
# ...          ...       ...  ...         ...                ...
# 30212   Biologia    2014.1  ...         4,8                  0
# 30213     Letras    2010.2  ...         7,3                  0
# 30214     Letras    2014.1  ...        2,25                  1
# 30215     Letras    2014.1  ...           0                  1
# 30216   Biologia    2014.2  ...         4,2                  0
#
# [30217 rows x 63 columns]

# %%
# Selecionando somente algumas colunas
df = pd.read_csv("baseGeral.csv", encoding = "UTF-8", sep = ";", usecols=["Curso", "Semestre"])
df
# Out:
#            Curso  Semestre
# 0      Pedagogia    2014.2
# 1       Biologia    2013.2
# 2      Pedagogia    2014.1
# 3      Pedagogia    2016.1
# 4       Biologia    2013.2
# ...          ...       ...
# 30212   Biologia    2014.1
# 30213     Letras    2010.2
# 30214     Letras    2014.1
# 30215     Letras    2014.1
# 30216   Biologia    2014.2
#
# [30217 rows x 2 columns]

# %%
# Lendo X linhas do arquivo
df = pd.read_csv("baseGeral.csv", encoding = "UTF-8", sep = ";", usecols=["Nome do Aluno"], nrows=5)
df
# Out:
#                                   Nome do Aluno
# 0  Ana Paula Oliveira dos Santos_Ped Gar 2012.2
# 1                     WAGNER  MACEDO CAVALCANTI
# 2                           LUIS DA SILVA SOUZA
# 3                                 Maria Gildete
# 4              LEANDRA SANTOS DE MOURA CURSANDO

# %%
df["Curso_e_Semestre"] = df["Curso"] + " " + df["Semestre"]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Curso'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-1d93361d81cb> in <module>()
# ...
